# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示
from zipfile import ZipFile
import numpy as np
import pandas as pd
import datetime
import gc

# %%
import sys
import random
import math
import os
from operator import itemgetter

from collections import defaultdict

random.seed(0)


class UserBasedCF(object):
    ''' TopN recommendation - User Based Collaborative Filtering '''

    # 构造函数，用来初始化
    def __init__(self):
        # 定义 训练集 测试集 为字典类型
        self.trainset = {}
        self.testset = {}
        # 训练集用的相似用户数
        self.n_sim_user = 30
        # 推荐Item数量
        self.n_rec_item = 30

        self.user_sim_mat = {}
        self.item_popular = {}
        self.item_count = 0
        # sys.stderr 是用来重定向标准错误信息的
        print('相似用户数目为 = %d' % self.n_sim_user, file=sys.stderr)
        print('推荐Item数目为 = %d' %
              self.n_rec_item, file=sys.stderr)

    # 划分训练集和测试集 pivot用来定义训练集和测试集的比例
    def generate_dataset(self, train, test=None, pivot=0.90):
        ''' load rating data and split it to training set and test set '''
        trainset_len = 0
        testset_len = 0
        if test is None:  # 随机分配验证机实验
            print('算法尝试！')
            for line in train.iterrows():
                user, item, rating = line[1][0], line[1][1], 1
                # split the data by pivot
                if random.random() < pivot:
                    self.trainset.setdefault(user, {})
                    self.trainset[user][item] = int(rating)
                    trainset_len += 1
                else:
                    self.testset.setdefault(user, {})
                    self.testset[user][item] = int(rating)
                    testset_len += 1
        else:  # 真正预测
            print('预测尝试！')
            for line in train.iterrows():
                user, item, rating = line[1][0], line[1][1], 1
                # split the data by pivot
                self.trainset.setdefault(user, {})
                self.trainset[user][item] = int(rating)
                trainset_len += 1
            del user, item, rating
            for line in test.iterrows():
                user, item, rating = line[1][0], line[1][1], 1
                self.testset.setdefault(user, {})
                self.testset[user][item] = int(rating)
                testset_len += 1

        print('split training set and test set succ')
        print('train set = %s' % trainset_len)
        print('test set = %s' % testset_len)

    # 建立物品-用户 倒排表
    def calc_user_sim(self):
        ''' calculate user similarity matrix '''
        # build inverse table for item-users
        # key=itemID, value=list of userIDs who have seen this item
        print('构建物品-用户倒排表中，请等待......', file=sys.stderr)
        item2users = dict()

        # Python 字典(Dictionary) items() 函数以列表返回可遍历的(键, 值) 元组数组
        for user, items in self.trainset.items():
            for item in items:
                # inverse table for item-users
                if item not in item2users:
                    # 根据商品id 构造set() 函数创建一个无序不重复元素集
                    item2users[item] = set()
                # 集合中值为用户id
                # 数值形如
                # {'914': {'1','6','10'}, '3408': {'1'} ......}
                item2users[item].add(user)
                # 记录电影的流行度
                if item not in self.item_popular:
                    self.item_popular[item] = 0
                self.item_popular[item] += 1
        print('构建物品-用户倒排表成功', file=sys.stderr)

        # save the total item number, which will be used in evaluation
        self.item_count = len(item2users)
        print('总共被操作过的物品数目为 = %d' % self.item_count, file=sys.stderr)

        # count co-rated items between users
        usersim_mat = self.user_sim_mat

        print('building user co-rated items matrix...', file=sys.stderr)
        # 令系数矩阵 C[u][v]表示N(u)∩N（v) ，假如用户u和用户v同时属于K个物品对应的用户列表，就有C[u][v]=K
        for item, users in item2users.items():
            for u in users:
                usersim_mat.setdefault(u, defaultdict(int))
                for v in users:
                    if u == v:
                        continue
                    usersim_mat[u][v] += 1
        print('build user co-rated items matrix succ', file=sys.stderr)

        # calculate similarity matrix
        print('calculating user similarity matrix...', file=sys.stderr)
        simfactor_count = 0
        PRINT_STEP = 2000000
        # 循环遍历usersim_mat 根据余弦相似度公式计算出用户兴趣相似度
        for u, related_users in usersim_mat.items():
            for v, count in related_users.items():
                # 以下是公式计算过程
                usersim_mat[u][v] = count / math.sqrt(
                    len(self.trainset[u]) * len(self.trainset[v]))
                # 计数 并没有什么卵用
                simfactor_count += 1
                if simfactor_count % PRINT_STEP == 0:
                    print('calculating user similarity factor(%d)' %
                          simfactor_count, file=sys.stderr)

        print('calculate user similarity matrix(similarity factor) succ',
              file=sys.stderr)
        print('Total similarity factor number = %d' %
              simfactor_count, file=sys.stderr)

    # 根据用户给予推荐结果
    def recommend(self, user, predict=False):
        '''定义给定K个相似用户和推荐N个商品'''
        K = self.n_sim_user
        N = self.n_rec_item
        # 定义一个字典来存储为用户推荐的电影
        rank = dict()

        watched_items = self.trainset[user]
        # sorted() 函数对所有可迭代的对象进行排序操作。 key 指定比较的对象 ，reverse=True 降序
        for similar_user, similarity_factor in sorted(self.user_sim_mat[user].items(),
                                                      key=itemgetter(1), reverse=True)[0:K]:
            for item in self.trainset[similar_user]:
                # 判断 如果这个商品 该用户已经买过 则跳出循环 ##此处不太成立
                #                 if item in watched_items:
                #                     continue
                # 记录用户对推荐的电影的兴趣度
                rank.setdefault(item, 0)
                rank[item] += similarity_factor
        # return the N best items
        return sorted(rank.items(), key=itemgetter(1), reverse=True)[0:N]

    def predict(self):
        print('Predict start...')

        N = self.n_rec_item
        #  varables for precision and recall
        hit = 0
        rec_count = 0
        test_count = 0
        # varables for coverage
        all_rec_items = set()
        # varables for popularity
        popular_sum = 0
        predict_result = []
        for i, user in enumerate(self.testset):
            if i % 500 == 0:
                print('recommended for %d users' % i)
            rec_items = self.recommend(user, predict=True)
            predict_result.append((user, rec_items))
        print('Predict end...')
        return predict_result

    # 计算 准确略，召回率，覆盖率，流行度
    def evaluate(self):

        ''' print evaluation result: precision, recall, coverage and popularity '''
        print('Evaluation start...', file=sys.stderr)

        N = self.n_rec_item
        #  varables for precision and recall
        # 记录推荐正确的电影数
        hit = 0
        # 记录推荐电影的总数
        rec_count = 0
        # 记录测试数据中总数
        test_count = 0
        # varables for coverage
        all_rec_items = set()
        # varables for popularity
        popular_sum = 0

        for i, user in enumerate(self.trainset):
            if i % 500 == 0:
                print('recommended for %d users' % i, file=sys.stderr)
            test_items = self.testset.get(user, {})
            rec_items = self.recommend(user, predict=False)
            for item, _ in rec_items:
                if item in test_items:
                    hit += 1
                all_rec_items.add(item)
                popular_sum += math.log(1 + self.item_popular[item])
            rec_count += N
            test_count += len(test_items)
        # 计算准确度
        precision = hit / (1.0 * rec_count)
        # 计算召回率
        recall = hit / (1.0 * test_count)
        # 计算覆盖率
        coverage = len(all_rec_items) / (1.0 * self.item_count)
        # 计算流行度
        popularity = popular_sum / (1.0 * rec_count)

        print('precision=%.4f\trecall=%.4f\tcoverage=%.4f\tpopularity=%.4f' %
              (precision, recall, coverage, popularity), file=sys.stderr)

# %%
import pandas as pd

# %%
train=pd.read_csv("H:\\pythonchengx_u\\Ecomme AI\\Date\\train_item")
test=pd.read_csv("H:\\pythonchengx_u\\Ecomme AI\\Date\\test_item")

# %%
train.head()
# Out:
#       user_id     item_id
# 0  1076667570   340804045
# 1  1076667570   273994489
# 2  1076667570   142049606
# 3  1076667570  1224612971
# 4  1076667570   525100650

# %%
usercf_pred = UserBasedCF()
# Out:
# 相似用户数目为 = 30
# 推荐Item数目为 = 30

# %%
usercf_pred.generate_dataset(train[['user_id','item_id']],test[['user_id','item_id']])
# Out:
# 预测尝试！
# split training set and test set succ
# train set = 6010979
# test set = 5252516

# %%
usercf_pred.calc_user_sim()
# Out:
# 构建物品-用户倒排表中，请等待......
# 构建物品-用户倒排表成功
# 总共被操作过的物品数目为 = 1347477
# building user co-rated items matrix...
# build user co-rated items matrix succ
# calculating user similarity matrix...
# calculating user similarity factor(2000000)
# calculating user similarity factor(4000000)
# calculating user similarity factor(6000000)
# calculating user similarity factor(8000000)
# calculating user similarity factor(10000000)
# calculating user similarity factor(12000000)
# calculating user similarity factor(14000000)
# calculating user similarity factor(16000000)
# calculating user similarity factor(18000000)
# calculating user similarity factor(20000000)
# calculating user similarity factor(22000000)
# calculating user similarity factor(24000000)
# calculating user similarity factor(26000000)
# calculating user similarity factor(28000000)
# calculating user similarity factor(30000000)
# calculating user similarity factor(32000000)
# calculating user similarity factor(34000000)
# calculating user similarity factor(36000000)
# calculating user similarity factor(38000000)
# calculating user similarity factor(40000000)
# calculating user similarity factor(42000000)
# calculating user similarity factor(44000000)
# calculating user similarity factor(46000000)
# calculating user similarity factor(48000000)
# calculating user similarity factor(50000000)
# calculating user similarity factor(52000000)
# calculating user similarity factor(54000000)
# calculating user similarity factor(56000000)
# calculating user similarity factor(58000000)
# calculating user similarity factor(60000000)
# calculating user similarity factor(62000000)
# calculating user similarity factor(64000000)
# calculating user similarity factor(66000000)
# calculating user similarity factor(68000000)
# calculating user similarity factor(70000000)
# calculating user similarity factor(72000000)
# calculating user similarity factor(74000000)
# calculating user similarity factor(76000000)
# calculating user similarity factor(78000000)
# calculating user similarity factor(80000000)
# calculating user similarity factor(82000000)
# calculating user similarity factor(84000000)
# calculating user similarity factor(86000000)
# calculating user similarity factor(88000000)
# calculating user similarity factor(90000000)
# calculating user similarity factor(92000000)
# calculating user similarity factor(94000000)
# calculating user similarity factor(96000000)
# calculating user similarity factor(98000000)
# calculating user similarity factor(100000000)
# calculating user similarity factor(102000000)
# calculating user similarity factor(104000000)
# calculating user similarity factor(106000000)
# calculating user similarity factor(108000000)
# calculating user similarity factor(110000000)
# calculating user similarity factor(112000000)
# calculating user similarity factor(114000000)
# calculating user similarity factor(116000000)
# calculating user similarity factor(118000000)
# calculating user similarity factor(120000000)
# calculating user similarity factor(122000000)
# calculating user similarity factor(124000000)
# calculating user similarity factor(126000000)
# calculating user similarity factor(128000000)
# calculating user similarity factor(130000000)
# calculating user similarity factor(132000000)
# calculating user similarity factor(134000000)
# calculating user similarity factor(136000000)
# calculating user similarity factor(138000000)
# calculating user similarity factor(140000000)
# calculating user similarity factor(142000000)
# calculating user similarity factor(144000000)
# calculating user similarity factor(146000000)
# calculating user similarity factor(148000000)
# calculating user similarity factor(150000000)
# calculating user similarity factor(152000000)
# calculating user similarity factor(154000000)
# calculating user similarity factor(156000000)
# calculating user similarity factor(158000000)
# calculating user similarity factor(160000000)
# calculating user similarity factor(162000000)
# calculating user similarity factor(164000000)
# calculating user similarity factor(166000000)
# calculating user similarity factor(168000000)
# calculating user similarity factor(170000000)
# calculating user similarity factor(172000000)
# calculating user similarity factor(174000000)
# calculating user similarity factor(176000000)
# calculating user similarity factor(178000000)
# calculating user similarity factor(180000000)
# calculating user similarity factor(182000000)
# calculating user similarity factor(184000000)
# calculating user similarity factor(186000000)
# calculating user similarity factor(188000000)
# calculating user similarity factor(190000000)
# calculating user similarity factor(192000000)
# calculating user similarity factor(194000000)
# calculating user similarity factor(196000000)
# calculating user similarity factor(198000000)
# calculating user similarity factor(200000000)
# calculating user similarity factor(202000000)
# calculating user similarity factor(204000000)
# calculating user similarity factor(206000000)
# calculating user similarity factor(208000000)
# calculating user similarity factor(210000000)
# calculating user similarity factor(212000000)
# calculating user similarity factor(214000000)
# calculating user similarity factor(216000000)
# calculating user similarity factor(218000000)
# calculating user similarity factor(220000000)
# calculating user similarity factor(222000000)
# calculating user similarity factor(224000000)
# calculating user similarity factor(226000000)
# calculating user similarity factor(228000000)
# calculating user similarity factor(230000000)
# calculating user similarity factor(232000000)
# calculating user similarity factor(234000000)
# calculating user similarity factor(236000000)
# calculating user similarity factor(238000000)
# calculating user similarity factor(240000000)
# calculating user similarity factor(242000000)
# calculating user similarity factor(244000000)
# calculating user similarity factor(246000000)
# calculating user similarity factor(248000000)
# calculating user similarity factor(250000000)
# calculating user similarity factor(252000000)
# calculating user similarity factor(254000000)
# calculating user similarity factor(256000000)
# calculating user similarity factor(258000000)
# calculating user similarity factor(260000000)
# calculating user similarity factor(262000000)
# calculating user similarity factor(264000000)
# calculating user similarity factor(266000000)
# calculating user similarity factor(268000000)
# calculating user similarity factor(270000000)
# calculating user similarity factor(272000000)
# calculating user similarity factor(274000000)
# calculating user similarity factor(276000000)
# calculating user similarity factor(278000000)
# calculating user similarity factor(280000000)
# calculating user similarity factor(282000000)
# calculating user similarity factor(284000000)
# calculating user similarity factor(286000000)
# calculating user similarity factor(288000000)
# calculating user similarity factor(290000000)
# calculating user similarity factor(292000000)
# calculating user similarity factor(294000000)
# calculating user similarity factor(296000000)
# calculating user similarity factor(298000000)
# calculating user similarity factor(300000000)
# calculating user similarity factor(302000000)
# calculating user similarity factor(304000000)
# calculating user similarity factor(306000000)
# calculating user similarity factor(308000000)
# calculating user similarity factor(310000000)
# calculating user similarity factor(312000000)
# calculating user similarity factor(314000000)
# calculating user similarity factor(316000000)
# calculating user similarity factor(318000000)
# calculating user similarity factor(320000000)
# calculating user similarity factor(322000000)
# calculating user similarity factor(324000000)
# calculating user similarity factor(326000000)
# calculating user similarity factor(328000000)
# calculating user similarity factor(330000000)
# calculating user similarity factor(332000000)
# calculating user similarity factor(334000000)
# calculating user similarity factor(336000000)
# calculating user similarity factor(338000000)
# calculating user similarity factor(340000000)
# calculating user similarity factor(342000000)
# calculating user similarity factor(344000000)
# calculating user similarity factor(346000000)
# calculating user similarity factor(348000000)
# calculating user similarity factor(350000000)
# calculating user similarity factor(352000000)
# calculating user similarity factor(354000000)
# calculating user similarity factor(356000000)
# calculating user similarity factor(358000000)
# calculating user similarity factor(360000000)
# calculating user similarity factor(362000000)
# calculating user similarity factor(364000000)
# calculating user similarity factor(366000000)
# calculating user similarity factor(368000000)
# calculating user similarity factor(370000000)
# calculating user similarity factor(372000000)
# calculating user similarity factor(374000000)
# calculating user similarity factor(376000000)
# calculating user similarity factor(378000000)
# calculating user similarity factor(380000000)
# calculating user similarity factor(382000000)
# calculating user similarity factor(384000000)
# calculating user similarity factor(386000000)
# calculating user similarity factor(388000000)
# calculating user similarity factor(390000000)
# calculating user similarity factor(392000000)
# calculating user similarity factor(394000000)
# calculating user similarity factor(396000000)
# calculating user similarity factor(398000000)
# calculating user similarity factor(400000000)
# calculating user similarity factor(402000000)
# calculating user similarity factor(404000000)
# calculating user similarity factor(406000000)
# calculating user similarity factor(408000000)
# calculating user similarity factor(410000000)
# calculating user similarity factor(412000000)
# calculating user similarity factor(414000000)
# calculating user similarity factor(416000000)
# calculating user similarity factor(418000000)
# calculating user similarity factor(420000000)
# calculating user similarity factor(422000000)
# calculating user similarity factor(424000000)
# calculating user similarity factor(426000000)
# calculating user similarity factor(428000000)
# calculating user similarity factor(430000000)
# calculating user similarity factor(432000000)
# calculating user similarity factor(434000000)
# calculating user similarity factor(436000000)
# calculating user similarity factor(438000000)
# calculating user similarity factor(440000000)
# calculating user similarity factor(442000000)
# calculating user similarity factor(444000000)
# calculating user similarity factor(446000000)
# calculating user similarity factor(448000000)
# calculating user similarity factor(450000000)
# calculating user similarity factor(452000000)
# calculating user similarity factor(454000000)
# calculating user similarity factor(456000000)
# calculating user similarity factor(458000000)
# calculating user similarity factor(460000000)
# calculating user similarity factor(462000000)
# calculating user similarity factor(464000000)
# calculating user similarity factor(466000000)
# calculating user similarity factor(468000000)
# calculating user similarity factor(470000000)
# calculating user similarity factor(472000000)
# calculating user similarity factor(474000000)
# calculating user similarity factor(476000000)
# calculating user similarity factor(478000000)
# calculating user similarity factor(480000000)
# calculating user similarity factor(482000000)
# calculating user similarity factor(484000000)
# calculating user similarity factor(486000000)
# calculating user similarity factor(488000000)
# calculating user similarity factor(490000000)
# calculating user similarity factor(492000000)
# calculating user similarity factor(494000000)
# calculating user similarity factor(496000000)
# calculating user similarity factor(498000000)
# calculating user similarity factor(500000000)
# calculating user similarity factor(502000000)
# calculating user similarity factor(504000000)
# calculating user similarity factor(506000000)
# calculating user similarity factor(508000000)
# calculating user similarity factor(510000000)
# calculating user similarity factor(512000000)
# calculating user similarity factor(514000000)
# calculating user similarity factor(516000000)
# calculating user similarity factor(518000000)
# calculating user similarity factor(520000000)
# calculating user similarity factor(522000000)
# calculating user similarity factor(524000000)
# calculating user similarity factor(526000000)
# calculating user similarity factor(528000000)
# calculating user similarity factor(530000000)
# calculating user similarity factor(532000000)
# calculating user similarity factor(534000000)
# calculating user similarity factor(536000000)
# calculating user similarity factor(538000000)
# calculating user similarity factor(540000000)
# calculating user similarity factor(542000000)
# calculating user similarity factor(544000000)
# calculating user similarity factor(546000000)
# calculating user similarity factor(548000000)
# calculating user similarity factor(550000000)
# calculating user similarity factor(552000000)
# calculating user similarity factor(554000000)
# calculating user similarity factor(556000000)
# calculating user similarity factor(558000000)
# calculating user similarity factor(560000000)
# calculating user similarity factor(562000000)
# calculating user similarity factor(564000000)
# calculating user similarity factor(566000000)
# calculating user similarity factor(568000000)
# calculating user similarity factor(570000000)
# calculating user similarity factor(572000000)
# calculating user similarity factor(574000000)
# calculating user similarity factor(576000000)
# calculating user similarity factor(578000000)
# calculating user similarity factor(580000000)
# calculating user similarity factor(582000000)
# calculating user similarity factor(584000000)
# calculating user similarity factor(586000000)
# calculating user similarity factor(588000000)
# calculating user similarity factor(590000000)
# calculating user similarity factor(592000000)
# calculating user similarity factor(594000000)
# calculating user similarity factor(596000000)
# calculating user similarity factor(598000000)
# calculating user similarity factor(600000000)
# calculating user similarity factor(602000000)
# calculating user similarity factor(604000000)
# calculating user similarity factor(606000000)
# calculating user similarity factor(608000000)
# calculating user similarity factor(610000000)
# calculating user similarity factor(612000000)
# calculating user similarity factor(614000000)
# calculating user similarity factor(616000000)
# calculating user similarity factor(618000000)
# calculating user similarity factor(620000000)
# calculating user similarity factor(622000000)
# calculating user similarity factor(624000000)
# calculating user similarity factor(626000000)
# calculating user similarity factor(628000000)
# calculating user similarity factor(630000000)
# calculating user similarity factor(632000000)
# calculating user similarity factor(634000000)
# calculating user similarity factor(636000000)
# calculating user similarity factor(638000000)
# calculating user similarity factor(640000000)
# calculating user similarity factor(642000000)
# calculate user similarity matrix(similarity factor) succ
# Total similarity factor number = 643294768

# %%
result = usercf_pred.predict()
# Out:
# Predict start...
# recommended for 0 users
# recommended for 500 users
# recommended for 1000 users
# recommended for 1500 users
# recommended for 2000 users
# recommended for 2500 users
# recommended for 3000 users
# recommended for 3500 users
# recommended for 4000 users
# recommended for 4500 users
# recommended for 5000 users
# recommended for 5500 users
# recommended for 6000 users
# recommended for 6500 users
# recommended for 7000 users
# recommended for 7500 users
# recommended for 8000 users
# recommended for 8500 users
# recommended for 9000 users
# recommended for 9500 users
# recommended for 10000 users
# recommended for 10500 users
# recommended for 11000 users
# recommended for 11500 users
# recommended for 12000 users
# recommended for 12500 users
# recommended for 13000 users
# recommended for 13500 users
# recommended for 14000 users
# recommended for 14500 users
# recommended for 15000 users
# recommended for 15500 users
# recommended for 16000 users
# recommended for 16500 users
# recommended for 17000 users
# recommended for 17500 users
# recommended for 18000 users
# recommended for 18500 users
# recommended for 19000 users
# recommended for 19500 users
# recommended for 20000 users
# recommended for 20500 users
# recommended for 21000 users
# recommended for 21500 users
# recommended for 22000 users
# recommended for 22500 users
# recommended for 23000 users
# recommended for 23500 users
# recommended for 24000 users
# recommended for 24500 users
# recommended for 25000 users
# recommended for 25500 users
# recommended for 26000 users
# recommended for 26500 users
# recommended for 27000 users
# recommended for 27500 users
# recommended for 28000 users
# recommended for 28500 users
# recommended for 29000 users
# recommended for 29500 users
# recommended for 30000 users
# recommended for 30500 users
# recommended for 31000 users
# recommended for 31500 users
# recommended for 32000 users
# recommended for 32500 users
# recommended for 33000 users
# recommended for 33500 users
# recommended for 34000 users
# recommended for 34500 users
# recommended for 35000 users
# recommended for 35500 users
# recommended for 36000 users
# recommended for 36500 users
# recommended for 37000 users
# recommended for 37500 users
# recommended for 38000 users
# recommended for 38500 users
# recommended for 39000 users
# recommended for 39500 users
# recommended for 40000 users
# recommended for 40500 users
# recommended for 41000 users
# recommended for 41500 users
# recommended for 42000 users
# recommended for 42500 users
# recommended for 43000 users
# recommended for 43500 users
# recommended for 44000 users
# recommended for 44500 users
# recommended for 45000 users
# recommended for 45500 users
# recommended for 46000 users
# recommended for 46500 users
# recommended for 47000 users
# recommended for 47500 users
# recommended for 48000 users
# recommended for 48500 users
# recommended for 49000 users
# recommended for 49500 users
# recommended for 50000 users
# recommended for 50500 users
# recommended for 51000 users
# recommended for 51500 users
# recommended for 52000 users
# recommended for 52500 users
# recommended for 53000 users
# recommended for 53500 users
# recommended for 54000 users
# recommended for 54500 users
# recommended for 55000 users
# recommended for 55500 users
# recommended for 56000 users
# recommended for 56500 users
# recommended for 57000 users
# recommended for 57500 users
# recommended for 58000 users
# recommended for 58500 users
# recommended for 59000 users
# recommended for 59500 users
# recommended for 60000 users
# recommended for 60500 users
# recommended for 61000 users
# recommended for 61500 users
# recommended for 62000 users
# recommended for 62500 users
# recommended for 63000 users
# recommended for 63500 users
# recommended for 64000 users
# recommended for 64500 users
# recommended for 65000 users
# recommended for 65500 users
# recommended for 66000 users
# recommended for 66500 users
# recommended for 67000 users
# recommended for 67500 users
# recommended for 68000 users
# recommended for 68500 users
# recommended for 69000 users
# recommended for 69500 users
# recommended for 70000 users
# recommended for 70500 users
# recommended for 71000 users
# recommended for 71500 users
# recommended for 72000 users
# recommended for 72500 users
# recommended for 73000 users
# recommended for 73500 users
# recommended for 74000 users
# recommended for 74500 users
# recommended for 75000 users
# recommended for 75500 users
# recommended for 76000 users
# recommended for 76500 users
# recommended for 77000 users
# recommended for 77500 users
# recommended for 78000 users
# recommended for 78500 users
# recommended for 79000 users
# recommended for 79500 users
# recommended for 80000 users
# recommended for 80500 users
# recommended for 81000 users
# recommended for 81500 users
# recommended for 82000 users
# recommended for 82500 users
# recommended for 83000 users
# recommended for 83500 users
# recommended for 84000 users
# recommended for 84500 users
# recommended for 85000 users
# recommended for 85500 users
# recommended for 86000 users
# recommended for 86500 users
# recommended for 87000 users
# recommended for 87500 users
# recommended for 88000 users
# recommended for 88500 users
# recommended for 89000 users
# recommended for 89500 users
# recommended for 90000 users
# recommended for 90500 users
# recommended for 91000 users
# recommended for 91500 users
# recommended for 92000 users
# recommended for 92500 users
# recommended for 93000 users
# recommended for 93500 users
# recommended for 94000 users
# recommended for 94500 users
# recommended for 95000 users
# recommended for 95500 users
# recommended for 96000 users
# recommended for 96500 users
# recommended for 97000 users
# recommended for 97500 users
# recommended for 98000 users
# recommended for 98500 users
# recommended for 99000 users
# recommended for 99500 users
# recommended for 100000 users
# recommended for 100500 users
# recommended for 101000 users
# recommended for 101500 users
# recommended for 102000 users
# recommended for 102500 users
# recommended for 103000 users
# recommended for 103500 users
# recommended for 104000 users
# recommended for 104500 users
# recommended for 105000 users
# recommended for 105500 users
# recommended for 106000 users
# recommended for 106500 users
# recommended for 107000 users
# recommended for 107500 users
# recommended for 108000 users
# recommended for 108500 users
# recommended for 109000 users
# recommended for 109500 users
# recommended for 110000 users
# recommended for 110500 users
# recommended for 111000 users
# recommended for 111500 users
# recommended for 112000 users
# recommended for 112500 users
# recommended for 113000 users
# recommended for 113500 users
# recommended for 114000 users
# recommended for 114500 users
# recommended for 115000 users
# recommended for 115500 users
# recommended for 116000 users
# recommended for 116500 users
# recommended for 117000 users
# recommended for 117500 users
# recommended for 118000 users
# recommended for 118500 users
# recommended for 119000 users
# recommended for 119500 users
# recommended for 120000 users
# recommended for 120500 users
# recommended for 121000 users
# recommended for 121500 users
# recommended for 122000 users
# recommended for 122500 users
# recommended for 123000 users
# recommended for 123500 users
# recommended for 124000 users
# recommended for 124500 users
# recommended for 125000 users
# recommended for 125500 users
# recommended for 126000 users
# recommended for 126500 users
# recommended for 127000 users
# recommended for 127500 users
# recommended for 128000 users
# recommended for 128500 users
# recommended for 129000 users
# recommended for 129500 users
# recommended for 130000 users
# recommended for 130500 users
# recommended for 131000 users
# recommended for 131500 users
# recommended for 132000 users
# recommended for 132500 users
# recommended for 133000 users
# recommended for 133500 users
# recommended for 134000 users
# recommended for 134500 users
# recommended for 135000 users
# recommended for 135500 users
# recommended for 136000 users
# recommended for 136500 users
# recommended for 137000 users
# recommended for 137500 users
# recommended for 138000 users
# recommended for 138500 users
# recommended for 139000 users
# recommended for 139500 users
# recommended for 140000 users
# recommended for 140500 users
# recommended for 141000 users
# recommended for 141500 users
# recommended for 142000 users
# recommended for 142500 users
# recommended for 143000 users
# recommended for 143500 users
# recommended for 144000 users
# recommended for 144500 users
# recommended for 145000 users
# recommended for 145500 users
# recommended for 146000 users
# recommended for 146500 users
# recommended for 147000 users
# recommended for 147500 users
# recommended for 148000 users
# recommended for 148500 users
# recommended for 149000 users
# recommended for 149500 users
# recommended for 150000 users
# recommended for 150500 users
# recommended for 151000 users
# recommended for 151500 users
# recommended for 152000 users
# recommended for 152500 users
# recommended for 153000 users
# recommended for 153500 users
# recommended for 154000 users
# recommended for 154500 users
# recommended for 155000 users
# recommended for 155500 users
# recommended for 156000 users
# recommended for 156500 users
# recommended for 157000 users
# recommended for 157500 users
# recommended for 158000 users
# recommended for 158500 users
# recommended for 159000 users
# recommended for 159500 users
# recommended for 160000 users
# recommended for 160500 users
# recommended for 161000 users
# recommended for 161500 users
# recommended for 162000 users
# recommended for 162500 users
# recommended for 163000 users
# recommended for 163500 users
# recommended for 164000 users
# recommended for 164500 users
# recommended for 165000 users
# recommended for 165500 users
# recommended for 166000 users
# recommended for 166500 users
# recommended for 167000 users
# recommended for 167500 users
# recommended for 168000 users
# recommended for 168500 users
# recommended for 169000 users
# recommended for 169500 users
# recommended for 170000 users
# recommended for 170500 users
# recommended for 171000 users
# recommended for 171500 users
# recommended for 172000 users
# recommended for 172500 users
# recommended for 173000 users
# recommended for 173500 users
# recommended for 174000 users
# recommended for 174500 users
# recommended for 175000 users
# recommended for 175500 users
# recommended for 176000 users
# recommended for 176500 users
# recommended for 177000 users
# recommended for 177500 users
# recommended for 178000 users
# recommended for 178500 users
# recommended for 179000 users
# recommended for 179500 users
# recommended for 180000 users
# recommended for 180500 users
# recommended for 181000 users
# recommended for 181500 users
# recommended for 182000 users
# recommended for 182500 users
# recommended for 183000 users
# recommended for 183500 users
# recommended for 184000 users
# recommended for 184500 users
# recommended for 185000 users
# recommended for 185500 users
# recommended for 186000 users
# recommended for 186500 users
# recommended for 187000 users
# recommended for 187500 users
# recommended for 188000 users
# recommended for 188500 users
# recommended for 189000 users
# recommended for 189500 users
# recommended for 190000 users
# recommended for 190500 users
# recommended for 191000 users
# recommended for 191500 users
# recommended for 192000 users
# recommended for 192500 users
# recommended for 193000 users
# recommended for 193500 users
# recommended for 194000 users
# recommended for 194500 users
# recommended for 195000 users
# recommended for 195500 users
# recommended for 196000 users
# recommended for 196500 users
# recommended for 197000 users
# recommended for 197500 users
# recommended for 198000 users
# recommended for 198500 users
# recommended for 199000 users
# recommended for 199500 users
# recommended for 200000 users
# recommended for 200500 users
# recommended for 201000 users
# recommended for 201500 users
# recommended for 202000 users
# recommended for 202500 users
# recommended for 203000 users
# recommended for 203500 users
# recommended for 204000 users
# recommended for 204500 users
# recommended for 205000 users
# recommended for 205500 users
# recommended for 206000 users
# recommended for 206500 users
# recommended for 207000 users
# recommended for 207500 users
# recommended for 208000 users
# recommended for 208500 users
# recommended for 209000 users
# recommended for 209500 users
# recommended for 210000 users
# recommended for 210500 users
# recommended for 211000 users
# recommended for 211500 users
# recommended for 212000 users
# recommended for 212500 users
# recommended for 213000 users
# recommended for 213500 users
# recommended for 214000 users
# recommended for 214500 users
# recommended for 215000 users
# recommended for 215500 users
# recommended for 216000 users
# recommended for 216500 users
# recommended for 217000 users
# recommended for 217500 users
# recommended for 218000 users
# recommended for 218500 users
# recommended for 219000 users
# recommended for 219500 users
# recommended for 220000 users
# recommended for 220500 users
# recommended for 221000 users
# recommended for 221500 users
# recommended for 222000 users
# recommended for 222500 users
# recommended for 223000 users
# recommended for 223500 users
# recommended for 224000 users
# recommended for 224500 users
# recommended for 225000 users
# recommended for 225500 users
# recommended for 226000 users
# recommended for 226500 users
# recommended for 227000 users
# recommended for 227500 users
# recommended for 228000 users
# recommended for 228500 users
# recommended for 229000 users
# recommended for 229500 users
# recommended for 230000 users
# recommended for 230500 users
# recommended for 231000 users
# recommended for 231500 users
# recommended for 232000 users
# recommended for 232500 users
# recommended for 233000 users
# recommended for 233500 users
# recommended for 234000 users
# recommended for 234500 users
# recommended for 235000 users
# recommended for 235500 users
# recommended for 236000 users
# recommended for 236500 users
# recommended for 237000 users
# recommended for 237500 users
# recommended for 238000 users
# recommended for 238500 users
# recommended for 239000 users
# recommended for 239500 users
# recommended for 240000 users
# recommended for 240500 users
# recommended for 241000 users
# recommended for 241500 users
# recommended for 242000 users
# recommended for 242500 users
# recommended for 243000 users
# recommended for 243500 users
# recommended for 244000 users
# recommended for 244500 users
# recommended for 245000 users
# recommended for 245500 users
# recommended for 246000 users
# recommended for 246500 users
# recommended for 247000 users
# recommended for 247500 users
# recommended for 248000 users
# recommended for 248500 users
# recommended for 249000 users
# recommended for 249500 users
# recommended for 250000 users
# recommended for 250500 users
# recommended for 251000 users
# recommended for 251500 users
# recommended for 252000 users
# recommended for 252500 users
# recommended for 253000 users
# recommended for 253500 users
# recommended for 254000 users
# recommended for 254500 users
# recommended for 255000 users
# recommended for 255500 users
# recommended for 256000 users
# recommended for 256500 users
# recommended for 257000 users
# recommended for 257500 users
# recommended for 258000 users
# recommended for 258500 users
# recommended for 259000 users
# recommended for 259500 users
# recommended for 260000 users
# recommended for 260500 users
# recommended for 261000 users
# recommended for 261500 users
# recommended for 262000 users
# recommended for 262500 users
# recommended for 263000 users
# recommended for 263500 users
# recommended for 264000 users
# recommended for 264500 users
# recommended for 265000 users
# recommended for 265500 users
# recommended for 266000 users
# recommended for 266500 users
# recommended for 267000 users
# recommended for 267500 users
# recommended for 268000 users
# recommended for 268500 users
# recommended for 269000 users
# recommended for 269500 users
# recommended for 270000 users
# recommended for 270500 users
# recommended for 271000 users
# recommended for 271500 users
# recommended for 272000 users
# recommended for 272500 users
# recommended for 273000 users
# recommended for 273500 users
# recommended for 274000 users
# recommended for 274500 users
# recommended for 275000 users
# recommended for 275500 users
# recommended for 276000 users
# recommended for 276500 users
# recommended for 277000 users
# recommended for 277500 users
# recommended for 278000 users
# recommended for 278500 users
# recommended for 279000 users
# recommended for 279500 users
# recommended for 280000 users
# recommended for 280500 users
# recommended for 281000 users
# recommended for 281500 users
# recommended for 282000 users
# recommended for 282500 users
# recommended for 283000 users
# recommended for 283500 users
# recommended for 284000 users
# recommended for 284500 users
# recommended for 285000 users
# recommended for 285500 users
# recommended for 286000 users
# recommended for 286500 users
# recommended for 287000 users
# recommended for 287500 users
# recommended for 288000 users
# recommended for 288500 users
# recommended for 289000 users
# recommended for 289500 users
# recommended for 290000 users
# recommended for 290500 users
# recommended for 291000 users
# recommended for 291500 users
# recommended for 292000 users
# recommended for 292500 users
# recommended for 293000 users
# recommended for 293500 users
# recommended for 294000 users
# recommended for 294500 users
# recommended for 295000 users
# recommended for 295500 users
# recommended for 296000 users
# recommended for 296500 users
# recommended for 297000 users
# recommended for 297500 users
# recommended for 298000 users
# recommended for 298500 users
# recommended for 299000 users
# recommended for 299500 users
# recommended for 300000 users
# recommended for 300500 users
# recommended for 301000 users
# recommended for 301500 users
# recommended for 302000 users
# recommended for 302500 users
# recommended for 303000 users
# recommended for 303500 users
# recommended for 304000 users
# recommended for 304500 users
# recommended for 305000 users
# recommended for 305500 users
# recommended for 306000 users
# recommended for 306500 users
# recommended for 307000 users
# recommended for 307500 users
# recommended for 308000 users
# recommended for 308500 users
# recommended for 309000 users
# recommended for 309500 users
# recommended for 310000 users
# recommended for 310500 users
# recommended for 311000 users
# recommended for 311500 users
# recommended for 312000 users
# recommended for 312500 users
# recommended for 313000 users
# recommended for 313500 users
# recommended for 314000 users
# recommended for 314500 users
# recommended for 315000 users
# recommended for 315500 users
# recommended for 316000 users
# recommended for 316500 users
# recommended for 317000 users
# recommended for 317500 users
# recommended for 318000 users
# recommended for 318500 users
# recommended for 319000 users
# recommended for 319500 users
# recommended for 320000 users
# recommended for 320500 users
# recommended for 321000 users
# recommended for 321500 users
# recommended for 322000 users
# recommended for 322500 users
# recommended for 323000 users
# recommended for 323500 users
# recommended for 324000 users
# recommended for 324500 users
# recommended for 325000 users
# recommended for 325500 users
# recommended for 326000 users
# recommended for 326500 users
# recommended for 327000 users
# recommended for 327500 users
# recommended for 328000 users
# recommended for 328500 users
# recommended for 329000 users
# recommended for 329500 users
# recommended for 330000 users
# recommended for 330500 users
# recommended for 331000 users
# recommended for 331500 users
# recommended for 332000 users
# recommended for 332500 users
# recommended for 333000 users
# recommended for 333500 users
# recommended for 334000 users
# recommended for 334500 users
# recommended for 335000 users
# recommended for 335500 users
# recommended for 336000 users
# recommended for 336500 users
# recommended for 337000 users
# recommended for 337500 users
# recommended for 338000 users
# recommended for 338500 users
# recommended for 339000 users
# recommended for 339500 users
# recommended for 340000 users
# recommended for 340500 users
# recommended for 341000 users
# recommended for 341500 users
# recommended for 342000 users
# recommended for 342500 users
# recommended for 343000 users
# recommended for 343500 users
# recommended for 344000 users
# recommended for 344500 users
# recommended for 345000 users
# recommended for 345500 users
# recommended for 346000 users
# recommended for 346500 users
# recommended for 347000 users
# recommended for 347500 users
# recommended for 348000 users
# recommended for 348500 users
# recommended for 349000 users
# recommended for 349500 users
# recommended for 350000 users
# recommended for 350500 users
# recommended for 351000 users
# recommended for 351500 users
# recommended for 352000 users
# recommended for 352500 users
# recommended for 353000 users
# recommended for 353500 users
# recommended for 354000 users
# recommended for 354500 users
# recommended for 355000 users
# recommended for 355500 users
# recommended for 356000 users
# recommended for 356500 users
# recommended for 357000 users
# recommended for 357500 users
# recommended for 358000 users
# recommended for 358500 users
# recommended for 359000 users
# recommended for 359500 users
# recommended for 360000 users
# recommended for 360500 users
# recommended for 361000 users
# recommended for 361500 users
# recommended for 362000 users
# recommended for 362500 users
# recommended for 363000 users
# recommended for 363500 users
# recommended for 364000 users
# recommended for 364500 users
# recommended for 365000 users
# recommended for 365500 users
# recommended for 366000 users
# recommended for 366500 users
# recommended for 367000 users
# recommended for 367500 users
# recommended for 368000 users
# recommended for 368500 users
# recommended for 369000 users
# recommended for 369500 users
# recommended for 370000 users
# recommended for 370500 users
# recommended for 371000 users
# recommended for 371500 users
# recommended for 372000 users
# recommended for 372500 users
# recommended for 373000 users
# recommended for 373500 users
# recommended for 374000 users
# recommended for 374500 users
# recommended for 375000 users
# recommended for 375500 users
# recommended for 376000 users
# recommended for 376500 users
# recommended for 377000 users
# recommended for 377500 users
# recommended for 378000 users
# recommended for 378500 users
# recommended for 379000 users
# recommended for 379500 users
# recommended for 380000 users
# recommended for 380500 users
# recommended for 381000 users
# recommended for 381500 users
# recommended for 382000 users
# recommended for 382500 users
# recommended for 383000 users
# recommended for 383500 users
# recommended for 384000 users
# recommended for 384500 users
# recommended for 385000 users
# recommended for 385500 users
# recommended for 386000 users
# recommended for 386500 users
# recommended for 387000 users
# recommended for 387500 users
# recommended for 388000 users
# recommended for 388500 users
# recommended for 389000 users
# recommended for 389500 users
# recommended for 390000 users
# recommended for 390500 users
# recommended for 391000 users
# recommended for 391500 users
# recommended for 392000 users
# recommended for 392500 users
# recommended for 393000 users
# recommended for 393500 users
# recommended for 394000 users
# recommended for 394500 users
# recommended for 395000 users
# recommended for 395500 users
# recommended for 396000 users
# recommended for 396500 users
# recommended for 397000 users
# recommended for 397500 users
# recommended for 398000 users
# recommended for 398500 users
# recommended for 399000 users
# recommended for 399500 users
# recommended for 400000 users
# recommended for 400500 users
# recommended for 401000 users
# recommended for 401500 users
# recommended for 402000 users
# recommended for 402500 users
# recommended for 403000 users
# recommended for 403500 users
# recommended for 404000 users
# recommended for 404500 users
# recommended for 405000 users
# recommended for 405500 users
# recommended for 406000 users
# recommended for 406500 users
# recommended for 407000 users
# recommended for 407500 users
# recommended for 408000 users
# recommended for 408500 users
# recommended for 409000 users
# recommended for 409500 users
# recommended for 410000 users
# recommended for 410500 users
# recommended for 411000 users
# recommended for 411500 users
# recommended for 412000 users
# recommended for 412500 users
# recommended for 413000 users
# recommended for 413500 users
# recommended for 414000 users
# recommended for 414500 users
# recommended for 415000 users
# recommended for 415500 users
# recommended for 416000 users
# recommended for 416500 users
# recommended for 417000 users
# recommended for 417500 users
# recommended for 418000 users
# recommended for 418500 users
# recommended for 419000 users
# recommended for 419500 users
# recommended for 420000 users
# recommended for 420500 users
# recommended for 421000 users
# recommended for 421500 users
# recommended for 422000 users
# recommended for 422500 users
# recommended for 423000 users
# recommended for 423500 users
# recommended for 424000 users
# recommended for 424500 users
# recommended for 425000 users
# recommended for 425500 users
# recommended for 426000 users
# recommended for 426500 users
# recommended for 427000 users
# recommended for 427500 users
# recommended for 428000 users
# recommended for 428500 users
# recommended for 429000 users
# recommended for 429500 users
# recommended for 430000 users
# recommended for 430500 users
# recommended for 431000 users
# recommended for 431500 users
# recommended for 432000 users
# recommended for 432500 users
# recommended for 433000 users
# recommended for 433500 users
# recommended for 434000 users
# recommended for 434500 users
# recommended for 435000 users
# recommended for 435500 users
# recommended for 436000 users
# recommended for 436500 users
# recommended for 437000 users
# recommended for 437500 users
# recommended for 438000 users
# recommended for 438500 users
# recommended for 439000 users
# recommended for 439500 users
# recommended for 440000 users
# recommended for 440500 users
# recommended for 441000 users
# recommended for 441500 users
# recommended for 442000 users
# recommended for 442500 users
# recommended for 443000 users
# recommended for 443500 users
# recommended for 444000 users
# recommended for 444500 users
# recommended for 445000 users
# recommended for 445500 users
# recommended for 446000 users
# recommended for 446500 users
# recommended for 447000 users
# recommended for 447500 users
# recommended for 448000 users
# recommended for 448500 users
# recommended for 449000 users
# recommended for 449500 users
# recommended for 450000 users
# recommended for 450500 users
# recommended for 451000 users
# recommended for 451500 users
# recommended for 452000 users
# recommended for 452500 users
# recommended for 453000 users
# recommended for 453500 users
# recommended for 454000 users
# recommended for 454500 users
# recommended for 455000 users
# recommended for 455500 users
# recommended for 456000 users
# recommended for 456500 users
# recommended for 457000 users
# recommended for 457500 users
# recommended for 458000 users
# recommended for 458500 users
# recommended for 459000 users
# recommended for 459500 users
# recommended for 460000 users
# recommended for 460500 users
# recommended for 461000 users
# recommended for 461500 users
# recommended for 462000 users
# recommended for 462500 users
# recommended for 463000 users
# recommended for 463500 users
# recommended for 464000 users
# recommended for 464500 users
# recommended for 465000 users
# recommended for 465500 users
# recommended for 466000 users
# recommended for 466500 users
# recommended for 467000 users
# recommended for 467500 users
# recommended for 468000 users
# recommended for 468500 users
# recommended for 469000 users
# recommended for 469500 users
# recommended for 470000 users
# recommended for 470500 users
# recommended for 471000 users
# recommended for 471500 users
# recommended for 472000 users
# recommended for 472500 users
# recommended for 473000 users
# recommended for 473500 users
# recommended for 474000 users
# recommended for 474500 users
# recommended for 475000 users
# recommended for 475500 users
# recommended for 476000 users
# recommended for 476500 users
# recommended for 477000 users
# recommended for 477500 users
# recommended for 478000 users
# recommended for 478500 users
# recommended for 479000 users
# recommended for 479500 users
# recommended for 480000 users
# recommended for 480500 users
# recommended for 481000 users
# recommended for 481500 users
# recommended for 482000 users
# recommended for 482500 users
# recommended for 483000 users
# recommended for 483500 users
# recommended for 484000 users
# recommended for 484500 users
# recommended for 485000 users
# recommended for 485500 users
# recommended for 486000 users
# recommended for 486500 users
# recommended for 487000 users
# recommended for 487500 users
# recommended for 488000 users
# recommended for 488500 users
# recommended for 489000 users
# recommended for 489500 users
# recommended for 490000 users
# recommended for 490500 users
# recommended for 491000 users
# recommended for 491500 users
# recommended for 492000 users
# recommended for 492500 users
# recommended for 493000 users
# recommended for 493500 users
# recommended for 494000 users
# recommended for 494500 users
# recommended for 495000 users
# recommended for 495500 users
# recommended for 496000 users
# recommended for 496500 users
# recommended for 497000 users
# recommended for 497500 users
# recommended for 498000 users
# recommended for 498500 users
# recommended for 499000 users
# recommended for 499500 users
# recommended for 500000 users
# recommended for 500500 users
# recommended for 501000 users
# recommended for 501500 users
# recommended for 502000 users
# recommended for 502500 users
# recommended for 503000 users
# recommended for 503500 users
# recommended for 504000 users
# recommended for 504500 users
# recommended for 505000 users
# recommended for 505500 users
# recommended for 506000 users
# recommended for 506500 users
# recommended for 507000 users
# recommended for 507500 users
# recommended for 508000 users
# recommended for 508500 users
# recommended for 509000 users
# recommended for 509500 users
# recommended for 510000 users
# recommended for 510500 users
# recommended for 511000 users
# recommended for 511500 users
# recommended for 512000 users
# recommended for 512500 users
# recommended for 513000 users
# recommended for 513500 users
# recommended for 514000 users
# recommended for 514500 users
# recommended for 515000 users
# recommended for 515500 users
# recommended for 516000 users
# recommended for 516500 users
# recommended for 517000 users
# recommended for 517500 users
# recommended for 518000 users
# recommended for 518500 users
# recommended for 519000 users
# recommended for 519500 users
# recommended for 520000 users
# recommended for 520500 users
# recommended for 521000 users
# recommended for 521500 users
# recommended for 522000 users
# recommended for 522500 users
# recommended for 523000 users
# recommended for 523500 users
# recommended for 524000 users
# recommended for 524500 users
# recommended for 525000 users
# recommended for 525500 users
# recommended for 526000 users
# recommended for 526500 users
# recommended for 527000 users
# recommended for 527500 users
# recommended for 528000 users
# recommended for 528500 users
# recommended for 529000 users
# recommended for 529500 users
# recommended for 530000 users
# recommended for 530500 users
# recommended for 531000 users
# recommended for 531500 users
# recommended for 532000 users
# recommended for 532500 users
# recommended for 533000 users
# recommended for 533500 users
# recommended for 534000 users
# recommended for 534500 users
# recommended for 535000 users
# recommended for 535500 users
# recommended for 536000 users
# recommended for 536500 users
# recommended for 537000 users
# recommended for 537500 users
# recommended for 538000 users
# recommended for 538500 users
# recommended for 539000 users
# recommended for 539500 users
# recommended for 540000 users
# recommended for 540500 users
# recommended for 541000 users
# recommended for 541500 users
# recommended for 542000 users
# recommended for 542500 users
# recommended for 543000 users
# recommended for 543500 users
# recommended for 544000 users
# recommended for 544500 users
# recommended for 545000 users
# recommended for 545500 users
# recommended for 546000 users
# recommended for 546500 users
# recommended for 547000 users
# recommended for 547500 users
# recommended for 548000 users
# recommended for 548500 users
# recommended for 549000 users
# recommended for 549500 users
# recommended for 550000 users
# recommended for 550500 users
# recommended for 551000 users
# recommended for 551500 users
# recommended for 552000 users
# recommended for 552500 users
# recommended for 553000 users
# recommended for 553500 users
# recommended for 554000 users
# recommended for 554500 users
# recommended for 555000 users
# recommended for 555500 users
# recommended for 556000 users
# recommended for 556500 users
# recommended for 557000 users
# recommended for 557500 users
# recommended for 558000 users
# recommended for 558500 users
# recommended for 559000 users
# recommended for 559500 users
# recommended for 560000 users
# recommended for 560500 users
# recommended for 561000 users
# recommended for 561500 users
# recommended for 562000 users
# recommended for 562500 users
# recommended for 563000 users
# recommended for 563500 users
# recommended for 564000 users
# recommended for 564500 users
# recommended for 565000 users
# recommended for 565500 users
# recommended for 566000 users
# recommended for 566500 users
# recommended for 567000 users
# recommended for 567500 users
# recommended for 568000 users
# recommended for 568500 users
# recommended for 569000 users
# recommended for 569500 users
# recommended for 570000 users
# recommended for 570500 users
# recommended for 571000 users
# recommended for 571500 users
# recommended for 572000 users
# recommended for 572500 users
# recommended for 573000 users
# recommended for 573500 users
# recommended for 574000 users
# recommended for 574500 users
# recommended for 575000 users
# recommended for 575500 users
# recommended for 576000 users
# recommended for 576500 users
# recommended for 577000 users
# recommended for 577500 users
# recommended for 578000 users
# recommended for 578500 users
# recommended for 579000 users
# recommended for 579500 users
# recommended for 580000 users
# recommended for 580500 users
# recommended for 581000 users
# recommended for 581500 users
# recommended for 582000 users
# recommended for 582500 users
# recommended for 583000 users
# recommended for 583500 users
# recommended for 584000 users
# recommended for 584500 users
# recommended for 585000 users
# recommended for 585500 users
# recommended for 586000 users
# recommended for 586500 users
# recommended for 587000 users
# recommended for 587500 users
# recommended for 588000 users
# recommended for 588500 users
# recommended for 589000 users
# recommended for 589500 users
# recommended for 590000 users
# recommended for 590500 users
# recommended for 591000 users
# recommended for 591500 users
# recommended for 592000 users
# recommended for 592500 users
# recommended for 593000 users
# recommended for 593500 users
# recommended for 594000 users
# recommended for 594500 users
# recommended for 595000 users
# recommended for 595500 users
# recommended for 596000 users
# recommended for 596500 users
# recommended for 597000 users
# recommended for 597500 users
# recommended for 598000 users
# recommended for 598500 users
# recommended for 599000 users
# recommended for 599500 users
# recommended for 600000 users
# recommended for 600500 users
# recommended for 601000 users
# recommended for 601500 users
# recommended for 602000 users
# recommended for 602500 users
# recommended for 603000 users
# recommended for 603500 users
# recommended for 604000 users
# recommended for 604500 users
# recommended for 605000 users
# recommended for 605500 users
# recommended for 606000 users
# recommended for 606500 users
# recommended for 607000 users
# recommended for 607500 users
# recommended for 608000 users
# recommended for 608500 users
# recommended for 609000 users
# recommended for 609500 users
# recommended for 610000 users
# recommended for 610500 users
# recommended for 611000 users
# recommended for 611500 users
# recommended for 612000 users
# recommended for 612500 users
# recommended for 613000 users
# recommended for 613500 users
# recommended for 614000 users
# recommended for 614500 users
# recommended for 615000 users
# recommended for 615500 users
# recommended for 616000 users
# recommended for 616500 users
# recommended for 617000 users
# recommended for 617500 users
# recommended for 618000 users
# recommended for 618500 users
# recommended for 619000 users
# recommended for 619500 users
# recommended for 620000 users
# recommended for 620500 users
# recommended for 621000 users
# recommended for 621500 users
# recommended for 622000 users
# recommended for 622500 users
# recommended for 623000 users
# recommended for 623500 users
# recommended for 624000 users
# recommended for 624500 users
# recommended for 625000 users
# recommended for 625500 users
# recommended for 626000 users
# recommended for 626500 users
# recommended for 627000 users
# recommended for 627500 users
# recommended for 628000 users
# recommended for 628500 users
# recommended for 629000 users
# recommended for 629500 users
# recommended for 630000 users
# recommended for 630500 users
# recommended for 631000 users
# recommended for 631500 users
# recommended for 632000 users
# recommended for 632500 users
# recommended for 633000 users
# recommended for 633500 users
# recommended for 634000 users
# recommended for 634500 users
# recommended for 635000 users
# recommended for 635500 users
# recommended for 636000 users
# recommended for 636500 users
# recommended for 637000 users
# recommended for 637500 users
# recommended for 638000 users
# recommended for 638500 users
# recommended for 639000 users
# recommended for 639500 users
# recommended for 640000 users
# recommended for 640500 users
# recommended for 641000 users
# recommended for 641500 users
# recommended for 642000 users
# recommended for 642500 users
# recommended for 643000 users
# recommended for 643500 users
# recommended for 644000 users
# recommended for 644500 users
# recommended for 645000 users
# recommended for 645500 users
# recommended for 646000 users
# recommended for 646500 users
# recommended for 647000 users
# recommended for 647500 users
# recommended for 648000 users
# recommended for 648500 users
# recommended for 649000 users
# recommended for 649500 users
# recommended for 650000 users
# recommended for 650500 users
# recommended for 651000 users
# recommended for 651500 users
# recommended for 652000 users
# recommended for 652500 users
# recommended for 653000 users
# recommended for 653500 users
# recommended for 654000 users
# recommended for 654500 users
# recommended for 655000 users
# recommended for 655500 users
# recommended for 656000 users
# recommended for 656500 users
# recommended for 657000 users
# recommended for 657500 users
# recommended for 658000 users
# recommended for 658500 users
# recommended for 659000 users
# recommended for 659500 users
# recommended for 660000 users
# recommended for 660500 users
# recommended for 661000 users
# recommended for 661500 users
# recommended for 662000 users
# recommended for 662500 users
# recommended for 663000 users
# recommended for 663500 users
# recommended for 664000 users
# recommended for 664500 users
# recommended for 665000 users
# recommended for 665500 users
# recommended for 666000 users
# recommended for 666500 users
# recommended for 667000 users
# recommended for 667500 users
# recommended for 668000 users
# recommended for 668500 users
# recommended for 669000 users
# recommended for 669500 users
# recommended for 670000 users
# recommended for 670500 users
# recommended for 671000 users
# recommended for 671500 users
# recommended for 672000 users
# recommended for 672500 users
# recommended for 673000 users
# recommended for 673500 users
# recommended for 674000 users
# recommended for 674500 users
# recommended for 675000 users
# recommended for 675500 users
# recommended for 676000 users
# recommended for 676500 users
# recommended for 677000 users
# recommended for 677500 users
# recommended for 678000 users
# recommended for 678500 users
# recommended for 679000 users
# recommended for 679500 users
# recommended for 680000 users
# recommended for 680500 users
# recommended for 681000 users
# recommended for 681500 users
# recommended for 682000 users
# recommended for 682500 users
# recommended for 683000 users
# recommended for 683500 users
# recommended for 684000 users
# recommended for 684500 users
# recommended for 685000 users
# recommended for 685500 users
# recommended for 686000 users
# recommended for 686500 users
# recommended for 687000 users
# recommended for 687500 users
# recommended for 688000 users
# recommended for 688500 users
# recommended for 689000 users
# recommended for 689500 users
# recommended for 690000 users
# recommended for 690500 users
# recommended for 691000 users
# recommended for 691500 users
# recommended for 692000 users
# recommended for 692500 users
# recommended for 693000 users
# recommended for 693500 users
# recommended for 694000 users
# recommended for 694500 users
# recommended for 695000 users
# recommended for 695500 users
# recommended for 696000 users
# recommended for 696500 users
# recommended for 697000 users
# recommended for 697500 users
# recommended for 698000 users
# recommended for 698500 users
# recommended for 699000 users
# recommended for 699500 users
# recommended for 700000 users
# recommended for 700500 users
# recommended for 701000 users
# recommended for 701500 users
# recommended for 702000 users
# recommended for 702500 users
# recommended for 703000 users
# recommended for 703500 users
# recommended for 704000 users
# recommended for 704500 users
# recommended for 705000 users
# recommended for 705500 users
# recommended for 706000 users
# recommended for 706500 users
# recommended for 707000 users
# recommended for 707500 users
# recommended for 708000 users
# recommended for 708500 users
# recommended for 709000 users
# recommended for 709500 users
# recommended for 710000 users
# recommended for 710500 users
# recommended for 711000 users
# recommended for 711500 users
# recommended for 712000 users
# recommended for 712500 users
# recommended for 713000 users
# recommended for 713500 users
# recommended for 714000 users
# recommended for 714500 users
# recommended for 715000 users
# recommended for 715500 users
# recommended for 716000 users
# recommended for 716500 users
# recommended for 717000 users
# recommended for 717500 users
# recommended for 718000 users
# recommended for 718500 users
# recommended for 719000 users
# recommended for 719500 users
# recommended for 720000 users
# recommended for 720500 users
# recommended for 721000 users
# recommended for 721500 users
# recommended for 722000 users
# recommended for 722500 users
# recommended for 723000 users
# recommended for 723500 users
# recommended for 724000 users
# recommended for 724500 users
# recommended for 725000 users
# recommended for 725500 users
# recommended for 726000 users
# Predict end...

# %%
import pickle
output = open('H:\\pythonchengx_u\\Ecomme AI\\Date\\Acom_user_cf.pkl', 'wb')
pickle.dump(usercf_pred, output)
output.close()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-0d3a8edea56d> in <module>
#       1 import pickle
#       2 output = open('H:\\pythonchengx_u\\Ecomme AI\\Date\\Acom_user_cf.pkl', 'wb')
# ----> 3 pickle.dump(usercf_pred, output)
#       4 output.close()
#       5
#
# MemoryError:

# %%
result_usercf = pd.DataFrame(result,columns=['user_id','rec_items'])
result_usercf['rec_items'] = result_usercf.rec_items.apply(lambda x:[i[0] for i in x])

# %%
result_usercf.to_csv("H:\\pythonchengx_u\\Ecomme AI\\Date\\usercfresult_df",index=False)

# %%
result_usercf.head()
# Out:
#       user_id                                          rec_items
# 0  1052625010  [921324564, 987952948, 1238296290, 921452260, ...
# 1  1067416116  [838402642, 1117779853, 1223899852, 1189876080...
# 2  1075634154  [905722239, 1145490924, 990276720, 895964786, ...
# 3  1013441031  [218105839, 1154534608, 475136298, 1216921275,...
# 4   129362515  [1109578253, 1066362270, 1036120431, 111301320...
